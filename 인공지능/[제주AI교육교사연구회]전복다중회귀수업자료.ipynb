# %% [markdown]
# # 전복(abalone) 데이터로 다중 회귀분석
#  - Abalone Dataset : 1994년 4177개 전복의 8개 속성을 나타냄
#  - 속성(feature)는 8개
#    - Length: 길이/최장 쉘 측정
#    - Diameter: 직경/길이에 수직
#    - Height: 두께/껍질과 살 포함
#    - Whole weight: 전체 무게/ 그램 단위
#    - Shucked weight: 살수율/ 그램 단위
#    - Viscera weight: 내장 무게/장 무게(출혈 후)
#    - Shell weight: 껍질 무게/건조 후
#    - Rings: -/+ 연도를 나타냄
#  - 참고자료(UCI저장소)
#    - http://archive.ics.uci.edu/ml/datasets/Abalone

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
#전복 빅데이터 4176개 8개 속성
#0 - 길이, 1 - 직경, 2 - 높이, 3 - 중량, 4 - 내장무게, 5 - 껍질무게, 6 - Rings, 7 - 살수율
url = 'https://drive.google.com/uc?export=download&id=161Zsr7r5mfnDfK-1YZApOQt-lZnRFFJ6'
df =

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4176 entries, 0 to 4175
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.455   4176 non-null   float64
#  1   0.365   4176 non-null   float64
#  2   0.095   4176 non-null   float64
#  3   0.514   4176 non-null   float64
#  4   0.101   4176 non-null   float64
#  5   0.15    4176 non-null   float64
#  6   15      4176 non-null   int64
#  7   0.2245  4176 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 261.1 KB
# None
#    0.455  0.365  0.095   0.514   0.101   0.15  15  0.2245
# 0  0.350  0.265  0.090  0.2255  0.0485  0.070   7  0.0995
# 1  0.530  0.420  0.135  0.6770  0.1415  0.210   9  0.2565
# 2  0.440  0.365  0.125  0.5160  0.1140  0.155  10  0.2155
# 3  0.330  0.255  0.080  0.2050  0.0395  0.055   7  0.0895
# 4  0.425  0.300  0.095  0.3515  0.0775  0.120   8  0.1410

# %%
#데이터값 입력
dataset = df.values
X = 
Y = 

#학습 데이터 70%, 테스트 데이터 30%로 나누기
X_train, X_test, Y_train, Y_test =

# %%
#1 - 모델구성
model = Sequential()

# %%
#2 - 모델 컴파일

# %%
#3 - 모델 학습

# %%
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
  label = Y_test[i]
  prediction = Y_prediction[i]
  print("실제살수율: {:.3f}, 학습후 예측살수율: {:.3f}".format(label, prediction))
# Out:
# 실제살수율: 0.619, 학습후 예측살수율: 0.624
# 실제살수율: 0.432, 학습후 예측살수율: 0.396
# 실제살수율: 0.209, 학습후 예측살수율: 0.193
# 실제살수율: 0.219, 학습후 예측살수율: 0.214
# 실제살수율: 0.320, 학습후 예측살수율: 0.309
# 실제살수율: 0.335, 학습후 예측살수율: 0.345
# 실제살수율: 0.154, 학습후 예측살수율: 0.150
# 실제살수율: 0.495, 학습후 예측살수율: 0.463
# 실제살수율: 0.344, 학습후 예측살수율: 0.312
# 실제살수율: 0.092, 학습후 예측살수율: 0.058

# %%
import matplotlib.pyplot as plt
#학습결과 확인

plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'],'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 모델 평가
model.evaluate(X_test, Y_test)
# Out:
# 40/40 [==============================] - 0s 905us/step - loss: 0.0015 - accuracy: 0.0000e+00
# [0.0014720112085342407, 0.0]

# %% [markdown]
# 과적합이란? 학습셋을 학습하다보면 어느 순간부터 정확도는 비슷하지만 테스트 오차가 늘어나는 현상

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![캡처.JPG](data:image/jpeg;base64,...)
