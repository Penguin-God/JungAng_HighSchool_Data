# %%
'''주제 : 전국 고등학교 수가 가장 많은 지역은 어디일까?

1. 데이터 수집
2. 결측치 확인
3. 데이터 수집을 위한 컬럼 추출 [학교명, 학교급구분,시도교육청명]
4. 고등학교 데이터 추출
5. 시도 교육청 별 정렬 및 갯수 세기
6. 선 그래프로 표현하기
7. 막대 그래프로 표현하기'''
# Out:
# '주제 : 전국 고등학교 수가 가장 많은 지역은 어디일까?\n\n1. 데이터 수집\n2. 결측치 확인\n3. 데이터 수집을 위한 컬럼 추출 [학교명, 학교급구분,시도교육청명]\n4. 고등학교 데이터 추출\n5. 시도 교육청 별 정렬 및 갯수 세기\n6. 선 그래프로 표현하기\n7. 막대 그래프로 표현하기'

# %%
#데이터 수집
import pandas as pd
import numpy as np

df=pd.read_csv('/content/학교.csv',encoding='cp949')

# %%
df
# Out:
#              학교ID       학교명 학교급구분  ...         위도          경도     데이터기준일자
# 0      B000012208  대구남산고등학교  고등학교  ...  35.857312  128.609179  2020-09-22
# 1      B000026354     고헌중학교   중학교  ...  35.597779  129.364027  2020-09-22
# 2      B000002653    서감초등학교  초등학교  ...  35.157820  128.982060  2020-09-22
# 3      B000009788     상장중학교   중학교  ...  37.150686  128.992122  2020-09-22
# 4      B000005015    맹방초등학교  초등학교  ...  37.398527  129.212777  2020-09-22
# ...           ...       ...   ...  ...        ...         ...         ...
# 11923  B000013415    아림고등학교  고등학교  ...  35.677677  127.913220  2020-09-22
# 11924  B000006498  순천성동초등학교  초등학교  ...  34.954332  127.486671  2020-09-22
# 11925  B000007909    단성초등학교  초등학교  ...  35.297390  127.955860  2020-09-22
# 11926  B000004312    서부초등학교  초등학교  ...  37.515743  127.162038  2020-09-22
# 11927  B000011779  경남간호고등학교  고등학교  ...  35.358041  128.084331  2020-09-22
#
# [11928 rows x 18 columns]

# %%
#전체 데이터 확인
df.head(5)
# Out:
#          학교ID       학교명 학교급구분  ...         위도          경도     데이터기준일자
# 0  B000012208  대구남산고등학교  고등학교  ...  35.857312  128.609179  2020-09-22
# 1  B000026354     고헌중학교   중학교  ...  35.597779  129.364027  2020-09-22
# 2  B000002653    서감초등학교  초등학교  ...  35.157820  128.982060  2020-09-22
# 3  B000009788     상장중학교   중학교  ...  37.150686  128.992122  2020-09-22
# 4  B000005015    맹방초등학교  초등학교  ...  37.398527  129.212777  2020-09-22
#
# [5 rows x 18 columns]

# %%
#데이터 정보 확인을 통한 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11928 entries, 0 to 11927
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   학교ID      11928 non-null  object
#  1   학교명       11928 non-null  object
#  2   학교급구분     11928 non-null  object
#  3   설립일자      11928 non-null  object
#  4   설립형태      11928 non-null  object
#  5   본교분교구분    11928 non-null  object
#  6   운영상태      11928 non-null  object
#  7   소재지지번주소   11928 non-null  object
#  8   소재지도로명주소  11928 non-null  object
#  9   시도교육청코드   11928 non-null  int64
#  10  시도교육청명    11928 non-null  object
#  11  교육지원청코드   11928 non-null  int64
#  12  교육지원청명    11928 non-null  object
#  13  생성일자      11928 non-null  object
#  14  변경일자      11927 non-null  object
#  15  위도        11928 non-null  float64
#  16  경도        11928 non-null  float64
#  17  데이터기준일자   11928 non-null  object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 1.6+ MB

# %%
#데이터 컬럼 확인
df.columns
# Out:
# Index(['학교ID', '학교명', '학교급구분', '설립일자', '설립형태', '본교분교구분', '운영상태', '소재지지번주소',
#        '소재지도로명주소', '시도교육청코드', '시도교육청명', '교육지원청코드', '교육지원청명', '생성일자', '변경일자',
#        '위도', '경도', '데이터기준일자'],
#       dtype='object')

# %%
#필요한 데이터 컬럼 추출
df1=df[['학교명','학교급구분','시도교육청명']]
df1
# Out:
#             학교명 학교급구분    시도교육청명
# 0      대구남산고등학교  고등학교  대구광역시교육청
# 1         고헌중학교   중학교  울산광역시교육청
# 2        서감초등학교  초등학교  부산광역시교육청
# 3         상장중학교   중학교    강원도교육청
# 4        맹방초등학교  초등학교    강원도교육청
# ...         ...   ...       ...
# 11923    아림고등학교  고등학교   경상남도교육청
# 11924  순천성동초등학교  초등학교   전라남도교육청
# 11925    단성초등학교  초등학교   경상남도교육청
# 11926    서부초등학교  초등학교    경기도교육청
# 11927  경남간호고등학교  고등학교   경상남도교육청
#
# [11928 rows x 3 columns]

# %%
#'학교급구분'데이터 중 고등학교만 데이터 추출
df2=df1[df1['학교급구분'] == '고등학교']
df2
# Out:
#                 학교명 학교급구분    시도교육청명
# 0          대구남산고등학교  고등학교  대구광역시교육청
# 14        부일외국어고등학교  고등학교  부산광역시교육청
# 16         삼성여자고등학교  고등학교  부산광역시교육청
# 21       서울문영여자고등학교  고등학교  서울특별시교육청
# 28           영신고등학교  고등학교  대구광역시교육청
# ...             ...   ...       ...
# 11912  대구농업마이스터고등학교  고등학교  대구광역시교육청
# 11913      위례한빛고등학교  고등학교    경기도교육청
# 11917      온양용화고등학교  고등학교   충청남도교육청
# 11923        아림고등학교  고등학교   경상남도교육청
# 11927      경남간호고등학교  고등학교   경상남도교육청
#
# [2373 rows x 3 columns]

# %%
#학교명에서 고등학교 문자열이 포함된 데이터 추출
df3=df1[df1['학교명'].str.contains('고등학교')]
df3
# Out:
#                 학교명 학교급구분    시도교육청명
# 0          대구남산고등학교  고등학교  대구광역시교육청
# 14        부일외국어고등학교  고등학교  부산광역시교육청
# 16         삼성여자고등학교  고등학교  부산광역시교육청
# 21       서울문영여자고등학교  고등학교  서울특별시교육청
# 28           영신고등학교  고등학교  대구광역시교육청
# ...             ...   ...       ...
# 11912  대구농업마이스터고등학교  고등학교  대구광역시교육청
# 11913      위례한빛고등학교  고등학교    경기도교육청
# 11917      온양용화고등학교  고등학교   충청남도교육청
# 11923        아림고등학교  고등학교   경상남도교육청
# 11927      경남간호고등학교  고등학교   경상남도교육청
#
# [2366 rows x 3 columns]

# %%
#시도 교육청 별 정렬 및 갯수 세기
df4=df2.groupby(by=['시도교육청명'], as_index=False).count()
df4
# Out:
#         시도교육청명  학교명  학교급구분
# 0       강원도교육청  116    116
# 1       경기도교육청  480    480
# 2      경상남도교육청  190    190
# 3      경상북도교육청  185    185
# 4     광주광역시교육청   67     67
# 5     대구광역시교육청   93     93
# 6     대전광역시교육청   62     62
# 7     부산광역시교육청  142    142
# 8     서울특별시교육청  320    320
# 9   세종특별자치시교육청   20     20
# 10    울산광역시교육청   58     58
# 11    인천광역시교육청  125    125
# 12     전라남도교육청  144    144
# 13     전라북도교육청  135    135
# 14  제주특별자치도교육청   34     34
# 15     충청남도교육청  118    118
# 16     충청북도교육청   84     84

# %%
#한글폰트 설치하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#나눔 글꼴 설치하기
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
#선그래프 그리기
import matplotlib.pyplot as plt
plt.plot(df4['시도교육청명'], df4['학교명'])
#x축 회전
plt.xticks(rotation=60)
plt.show()

# %%
#막대 그래프 그리기
import matplotlib.pyplot as plt
plt.bar(df4['시도교육청명'],df4['학교명'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #추가 위도,경도 데이터 활용하기

# %%
df

# %%
#전국 학교 경도, 위도 데이터로 표현하기
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10)) #캔버스사이즈 변경

경도=df['경도']
위도=df['위도']

plt.scatter(경도,위도)

plt.show()

# %% [markdown]
# <참고> 제주도 고등학교 지도에 표시하기(folium라이브러리)

# %%
#'학교명','학교급구분','시도교육청명','위도','경도' 컬럼추출
df5=df[['학교명','학교급구분','시도교육청명','위도','경도']]
df6=df5[df5['시도교육청명'].isin(['제주특별자치도교육청'])]
df7=df6[df6['학교급구분'].isin(['고등학교'])]
df7

# %%
#range(5)로 리스트 [0,1,2,3,4]를 만들어 print(i)를 5번 반복
for i in range(5):
  print(i)

# %%
#df7의 전체 데이터 갯수(길이)를 구함.
len(df7)

# %%
#folium 지도시각화를 위한 라이브러리
import folium
map_osm = folium.Map(location=[33.49130755,126.539486], zoom_start=12)
# 제주중앙여자고등학교 위도,경도 : 33.49130755,126.539486

map_osm # map출력
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df7

# %%
# 표기를 위한 인덱스 리셋
df7=df7.reset_index()
df7
# Out:
#     index                  학교명 학교급구분      시도교육청명         위도          경도
# 0    1861             제주과학고등학교  고등학교  제주특별자치도교육청  33.426620  126.531445
# 1    3994               한림고등학교  고등학교  제주특별자치도교육청  33.397751  126.258320
# 2    4117             삼성여자고등학교  고등학교  제주특별자치도교육청  33.254357  126.583574
# 3    4633               중문고등학교  고등학교  제주특별자치도교육청  33.254865  126.446895
# 4    4877               영주고등학교  고등학교  제주특별자치도교육청  33.454787  126.579764
# 5    5356               오현고등학교  고등학교  제주특별자치도교육청  33.517802  126.556449
# 6    5402             제주여자고등학교  고등학교  제주특별자치도교육청  33.483334  126.539762
# 7    5470               제주고등학교  고등학교  제주특별자치도교육청  33.472373  126.481671
# 8    5961              서귀포고등학교  고등학교  제주특별자치도교육청  33.257017  126.563108
# 9    6244               남녕고등학교  고등학교  제주특별자치도교육청  33.490057  126.481981
# 10   7109           제주중앙여자고등학교  고등학교  제주특별자치도교육청  33.491308  126.539486
# 11   7372               함덕고등학교  고등학교  제주특별자치도교육청  33.544584  126.651437
# 12   7706               표선고등학교  고등학교  제주특별자치도교육청  33.331157  126.826996
# 13   8051               애월고등학교  고등학교  제주특별자치도교육청  33.460219  126.333396
# 14   8510             한국뷰티고등학교  고등학교  제주특별자치도교육청  33.300078  126.181868
# 15   8631               성산고등학교  고등학교  제주특별자치도교육청  33.470203  126.915167
# 16   8785            NLCS JeJu  고등학교  제주특별자치도교육청  33.296843  126.291809
# 17   8845               세화고등학교  고등학교  제주특별자치도교육청  33.516197  126.862739
# 18   8987      KIS High School  고등학교  제주특별자치도교육청  33.288646  126.287220
# 19   9005             제주중앙고등학교  고등학교  제주특별자치도교육청  33.474170  126.573373
# 20   9068           제주여자상업고등학교  고등학교  제주특별자치도교육청  33.514671  126.536353
# 21   9104             대정여자고등학교  고등학교  제주특별자치도교육청  33.229189  126.253314
# 22   9347            서귀포여자고등학교  고등학교  제주특별자치도교육청  33.243496  126.530798
# 23   9430            제주외국어고등학교  고등학교  제주특별자치도교육청  33.433976  126.425979
# 24   9447               대기고등학교  고등학교  제주특별자치도교육청  33.492510  126.593279
# 25   9720               대정고등학교  고등학교  제주특별자치도교육청  33.231926  126.259500
# 26  10012             한림공업고등학교  고등학교  제주특별자치도교육청  33.406526  126.269912
# 27  10136             제주제일고등학교  고등학교  제주특별자치도교육청  33.480030  126.480705
# 28  10357          서귀포산업과학고등학교  고등학교  제주특별자치도교육청  33.297646  126.594767
# 29  10432               남주고등학교  고등학교  제주특별자치도교육청  33.276522  126.564968
# 30  10477      세인트존스베리 아카데미 제주  고등학교  제주특별자치도교육청  33.285293  126.284313
# 31  10504      제주대학교사범대학부설고등학교  고등학교  제주특별자치도교육청  33.513785  126.510240
# 32  10703  Branksome Hall Asia  고등학교  제주특별자치도교육청  33.289972  126.287265
# 33  11198             신성여자고등학교  고등학교  제주특별자치도교육청  33.476989  126.564068

# %%
#index 컬럼 삭제
df7=df7.drop(['index'],axis=1)

# %%
# df7 길이만큼 반복하며 i행의 위도,경도의 
for i in range(len(df7)):
  folium.Circle(df7.loc[i,['위도','경도']],radius=200).add_to(map_osm)
  folium.Marker(df7.loc[i,['위도','경도']]).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
